# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "../Resources/spectator_list.csv"
spectator_list_df = pd.read_csv(csv_file)
spectator_list_df.head()
# Out:
#    Unnamed: 0  Rank                                               Wine  Score  \
# 0           0     1  Tenuta San Guido Bolgheri-Sassicaia Sassicaia ...     97
# 1           1     2  Château Canon-La Gaffelière St.-Emilion 2015 +...     96
# 2           2     3  Castello di Volpaia Chianti Classico Riserva 2...     96
# 3           3     4  La Rioja Alta Rioja 890 Gran Reserva Selección...     95
# 4           4     5  Moët & Chandon Brut Champagne Dom Pérignon Leg...     96
#
#   Price
# 0  $245
# 1   $84
# 2   $35
# 3  $175
# 4  $180

# %%
wine_mag = "../Resources/winemag-data-130k-v2.csv"
winemag_df = pd.read_csv(wine_mag)
winemag_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
cutwine_mag_df=winemag_df[:100]

# %%
cutwine_mag_df
# Out:
#     Unnamed: 0   country                                        description  \
# 0            0     Italy  Aromas include tropical fruit, broom, brimston...
# 1            1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2            2        US  Tart and snappy, the flavors of lime flesh and...
# 3            3        US  Pineapple rind, lemon pith and orange blossom ...
# 4            4        US  Much like the regular bottling from 2012, this...
# ..         ...       ...                                                ...
# 95          95    France  This is a dense wine, packed with both tannins...
# 96          96    France  The wine comes from one of the cru estates fol...
# 97          97        US  A wisp of bramble extends a savory tone from n...
# 98          98     Italy  Forest floor, menthol, espresso, cranberry and...
# 99          99        US  This blends 20% each of all five red-Bordeaux ...
#
#                            designation  points  price           province  \
# 0                         Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                             Avidagos      87   15.0              Douro
# 2                                  NaN      87   14.0             Oregon
# 3                 Reserve Late Harvest      87   13.0           Michigan
# 4   Vintner's Reserve Wild Child Block      87   65.0             Oregon
# ..                                 ...     ...    ...                ...
# 95                                 NaN      88   20.0         Beaujolais
# 96                                 NaN      88   18.0         Beaujolais
# 97                      Ingle Vineyard      88   20.0           New York
# 98                        Dono Riserva      88   30.0            Tuscany
# 99         Intreccio Library Selection      88   75.0         California
#
#                  region_1           region_2         taster_name  \
# 0                    Etna                NaN       Kerin O’Keefe
# 1                     NaN                NaN          Roger Voss
# 2       Willamette Valley  Willamette Valley        Paul Gregutt
# 3     Lake Michigan Shore                NaN  Alexander Peartree
# 4       Willamette Valley  Willamette Valley        Paul Gregutt
# ..                    ...                ...                 ...
# 95               Juliénas                NaN          Roger Voss
# 96                 Régnié                NaN          Roger Voss
# 97           Finger Lakes       Finger Lakes  Anna Lee C. Iijima
# 98  Morellino di Scansano                NaN       Kerin O’Keefe
# 99            Napa Valley               Napa      Virginie Boone
#
#    taster_twitter_handle                                              title  \
# 0           @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1             @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2            @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                    NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4            @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# ..                   ...                                                ...
# 95            @vossroger                         Henry Fessy 2015  Juliénas
# 96            @vossroger                           Henry Fessy 2015  Régnié
# 97                   NaN  Heron Hill 2015 Ingle Vineyard Riesling (Finge...
# 98          @kerinokeefe  Serpaia di Endrizzi 2010 Dono Riserva  (Morell...
# 99               @vboone  Soquel Vineyards 2013 Intreccio Library Select...
#
#                      variety               winery
# 0                White Blend              Nicosia
# 1             Portuguese Red  Quinta dos Avidagos
# 2                 Pinot Gris            Rainstorm
# 3                   Riesling           St. Julian
# 4                 Pinot Noir         Sweet Cheeks
# ..                       ...                  ...
# 95                     Gamay          Henry Fessy
# 96                     Gamay          Henry Fessy
# 97                  Riesling           Heron Hill
# 98                Sangiovese  Serpaia di Endrizzi
# 99  Bordeaux-style Red Blend     Soquel Vineyards
#
# [100 rows x 14 columns]

# %%
# Create a filtered dataframe from specific columns
cutwine_magcol = ["country", "description", "designation","points","price","province","region_1","region_2","taster_name","taster_twitter_handle","title","variety","winery"]
newcutwine_magdf= cutwine_mag_df[cutwine_magcol].copy()

#Drop empty values 
cutwine_transformed.dropna(subset=['price'], inplace=True)

#Delete columns
wine_mag_list2= cutwine_transformed.drop(["country", "description", "designation","province","region_1","region_2","taster_name","taster_twitter_handle","variety","winery"], axis=1 )

# %%
#Rename the column headers
wine_mag_list= wine_mag_list2.rename(columns={"Wine Name": "title",
                                                          "Wine Price": "price",
                                                          "Wine Points": "points"})

# %%
wine_mag_list
# Out:
#      points  price                                              title
# 1        87   15.0      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        87   14.0      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        87   13.0  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        87   65.0  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5        87   15.0  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# ..      ...    ...                                                ...
# 96       88   18.0                           Henry Fessy 2015  Régnié
# 97       88   20.0  Heron Hill 2015 Ingle Vineyard Riesling (Finge...
# 98       88   30.0  Serpaia di Endrizzi 2010 Dono Riserva  (Morell...
# 99       88   75.0  Soquel Vineyards 2013 Intreccio Library Select...
# 100      88   18.0             Ventosa 2015 Pinot Gris (Finger Lakes)
#
# [93 rows x 3 columns]

# %%
#Create Database Connection
connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{connection_string}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-15671556ec62> in <module>
#       1 #Create Database Connection
#       2 connection_string = "postgres:postgres@localhost:5432/customer_db"
# ----> 3 engine = create_engine(f'postgresql://{connection_string}')
#
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     448     strategy = kwargs.pop("strategy", default_strategy)
#     449     strategy = strategies.strategies[strategy]
# --> 450     return strategy.create(*args, **kwargs)
#     451
#     452
#
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# //anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in dbapi(cls)
#     735     @classmethod
#     736     def dbapi(cls):
# --> 737         import psycopg2
#     738
#     739         return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
# Confirm tables
engine.table_names()

# %%
#Load the Dataframes
spectator_list_df.to_sql(name='Spectator List', con=engine, if_exists='append', index=True)
county_transformed.to_sql(name='Wine Magazine Reviews', con=engine, if_exists='append', index=True)
